# %% [markdown]
# # Fase 6: Implementación
#
# Como resultado del análisis exhaustivo y la evaluación comparativa de múltiples estrategias de modelado y ensamblaje, se propone implementar el Ensemble de modelos en el sistema de gestión del Hospital de Apoyo María Auxiliadora.
#
# ## 6.1. Objetivo de la implementación
#
# El objetivo primordial de este modelo de alta precisión y robustez es anticipar la probabilidad de asistencia de los pacientes a sus citas médicas programadas. Esto permitirá al hospital optimizar significativamente sus recursos (médicos, salas y equipamiento), reducir las inasistencias (con un objetivo crítico del 92% de detección de riesgo), mejorar la programación al ajustar dinámicamente la agenda médica, aumentar la eficiencia operativa al maximizar la utilización de slots disponibles y, consecuentemente, minimizar los costos asociados a recursos desperdiciados.
#
# ## 6.2. Propuesta de integración
#
# ### 6.2.1. Arquitectura de despliegue
#
# La arquitectura de despliegue se compone de tres elementos centrales. El Servidor de Modelos operará en un entorno local o cloud (como AWS SageMaker o Google Cloud AI Platform), alojando los 6 modelos base serializados (LGBM y XGBoost) y exponiéndolos a través de una API REST (FastAPI/Flask y Docker) para recibir datos y devolver predicciones. El Pipeline de Predicción se encargará de recibir las características del paciente, ejecutar el preprocesamiento automático, generar predicciones con los 6 modelos y, finalmente, agregarlas mediante un sistema de votación mayoritaria para retornar la predicción binaria, la probabilidad de asistencia y el nivel de confianza. La Base de Datos de Predicciones será fundamental para el monitoreo continuo, registrando el historial de todas las predicciones, los resultados reales (outcome) y las métricas de rendimiento calculadas periódicamente.
#
# ### 6.2.2. Modos de operación
#
# El sistema está diseñado para operar en dos modalidades principales. El Modo Batch (por lotes), ideal para la planificación estratégica, procesará diariamente o semanalmente todas las citas programadas, generando reportes de pacientes con alto riesgo. Por otro lado, el Modo Tiempo Real permitirá una predicción instantánea justo al momento de agendar una cita, ofreciendo una integración directa con el Sistema de Gestión Hospitalaria (HIS/EHR) para proporcionar feedback inmediato al personal administrativo.
#
# ### 6.2.3. Interfaz de usuario
#
# Se proponen tres opciones de interfaz para asegurar la adopción. La Opción 1 es un Dashboard Web Administrativo, un panel de control visual que mostrará la lista de citas con la probabilidad de asistencia y alertas para casos de alto riesgo. La Opción 2 consiste en la Integración con el Sistema Existente, embebiendo un módulo en el sistema actual de citas que muestre un indicador visual simple (semáforo) en cada cita. Finalmente, la Opción 3 contempla una Aplicación Móvil para Personal Médico, permitiendo la visualización de la agenda con predicciones incorporadas y acceso rápido desde cualquier ubicación del hospital.
#
# ### 6.2.4. Automatización de intervenciones
#
# El sistema implementará un Sistema de Alertas Inteligentes basado en el nivel de riesgo predicho. Para el Alto Riesgo (probabilidad < 50%), se activará una llamada telefónica automática y un SMS de recordatorio. En el caso de Riesgo Medio (50-70%), se enviará un SMS de recordatorio con la opción de reconfirmación vía WhatsApp. El Bajo Riesgo (> 70%) recibirá un recordatorio estándar automático. Adicionalmente, el sistema ejecutará una Optimización Dinámica de Agenda mediante sobreprogramación inteligente en slots con predicción de alta inasistencia y redistribución automática de pacientes en lista de espera, alertando al personal para los ajustes manuales necesarios.
#
# ## 6.3. Plan de monitoreo continuo
#
# ### 6.3.1. Métricas de seguimiento
#
# El monitoreo se centrará en tres áreas. Las Métricas de Rendimiento (evaluación mensual) incluirán el Accuracy en producción, el F1 Score, el Recall de la clase positiva (crítico mantenerlo > 90%), la Curva ROC, AUC y el Brier Score. Las Métricas Operacionales (evaluación semanal) se enfocarán en el tiempo de respuesta del API (objetivo < 100ms) y la disponibilidad del servicio (uptime > 99.5%). Finalmente, las Métricas de Negocio (evaluación mensual) medirán la reducción real de inasistencias (vs línea base), el ROI, la satisfacción del personal y la mejora en la utilización de slots de citas.
#
# ### 6.3.2. Detección de data drift
#
# Se establecerá un riguroso monitoreo de las características de entrada para detectar cualquier cambio (data drift). Esto incluye la vigilancia de la distribución de variables numéricas y la frecuencia de categorías, activándose alertas automáticas si la distribución de las features se desvía más de 2 desviaciones estándar respecto al entrenamiento o si el rendimiento del modelo cae más del 5% del baseline establecido.
#
# ### 6.3.3. Plan de reentrenamiento
#
# Se recomienda un plan de reentrenamiento periódico con un reentrenamiento completo cada 6 meses y un fine-tuning cada 3 meses utilizando nuevos datos. El reentrenamiento urgente se ejecutará ante la detección de drift significativo. El proceso incluye la recolección de datos nuevos, el análisis de la distribución y el re-balanceo si es necesario, el entrenamiento de nuevos modelos, una validación rigurosa en un conjunto de test reciente, y un A/B testing de dos semanas para asegurar que el nuevo modelo supere al actual antes del despliegue gradual.
#
# ## 6.4. Capacitación y adopción
#
# El Plan de Capacitación está diseñado para garantizar una adopción exitosa por rol. El Personal Administrativo recibirá 2 horas de formación centrada en la interpretación de probabilidades, el uso del dashboard y los protocolos de acción por nivel de riesgo. El Personal Médico tendrá una sesión de 1 hora para una visión general del sistema y sus beneficios en la optimización de agenda. El Equipo de TI dedicará 4 horas a la arquitectura técnica, monitoreo y el proceso de troubleshooting. El soporte se complementará con un Manual de Usuario, videotutoriales cortos y una sección de preguntas frecuentes (FAQ).
#
# ## 6.5. Consideraciones éticas y legales
#
# ### 6.5.1. Protección de datos
#
# Se garantiza el Cumplimiento Normativo adhiriéndose a la Ley N° 29733 (Ley de Protección de Datos Personales de Perú) y utilizando el Reglamento General de Protección de Datos (GDPR) como un estándar internacional, además de las normativas específicas del sector salud. Las Medidas de Seguridad incluirán la encriptación de datos en tránsito y en reposo, el control de acceso basado en roles (RBAC), auditoría de accesos, anonimización de datos para análisis agregados, y un plan de backup y recuperación ante desastres.
#
# ### 6.5.2. Uso ético del modelo
#
# El uso ético se basa en tres Principios clave: la transparencia sobre el uso de la IA, el monitoreo constante para asegurar la no discriminación, y la afirmación de que la Decisión Humana Final prevalece, siendo las predicciones solo una herramienta de apoyo. Esto establece claros Límites de Uso: las predicciones nunca se utilizarán para negar atención médica, influir en la priorización clínica de emergencias o sustituir la comunicación directa con el paciente.
#
# ### 6.5.3. Consentimiento informado
#
# El hospital establecerá una Política de Privacidad clara que detalle el uso de los datos para las predicciones, junto con una opción explícita de opt-out para aquellos pacientes que no deseen ser incluidos en el proceso. Esta información se hará accesible a través de cartelería y el sitio web institucional.
#
# ## 6.6. Roadmap de implementación
#
# La implementación se desarrollará en un plazo de seis meses, asegurando un despliegue controlado y validado en cada etapa.
#
# - Fase 1: Preparación (Mes 1): Finalización de la validación del modelo, preparación de la infraestructura, desarrollo de las interfaces y redacción de toda la documentación.
#
# - Fase 2: Piloto (Mes 2-3): Despliegue en un entorno de pruebas, capacitación de un equipo piloto, ejecución de la fase piloto con monitoreo intensivo, y recolección de feedback para ajustes.
#
# - Fase 3: Expansión gradual (Mes 4-5): Despliegue en especialidades adicionales, capacitación masiva, integración completa con el sistema hospitalario y refinamiento de las automatizaciones.
#
# - Fase 4: Operación completa (Mes 6+): Despliegue total, operación 24/7 con monitoreo continuo, evaluación del impacto y el ROI, y establecimiento del plan de mejora continua.
#
# ## 6.7. Métricas de éxito de la implementación
#
# El éxito se medirá a través de tres grupos de indicadores. Los KPIs de Adopción (primeros 3 meses) buscan alcanzar un >90% de personal capacitado y >95% de citas con predicción generada. Los KPIs de Impacto (6-12 meses) tienen como meta una reducción de la tasa de inasistencia >15% y una mejora en la utilización de slots >20%, demostrando un ROI positivo. Los KPIs Técnicos (continuos) garantizan el funcionamiento óptimo con un Uptime >99.5%, un tiempo de respuesta del API inferior a 100ms, y el mantenimiento de la Accuracy (>80%) y el Recall de la clase positiva (>90%).
#
# ## 6.8. Consideraciones finales
#
# La implementación del Global Ensemble representa un avance significativo hacia una gestión hospitalaria predictiva y eficiente. La solidez de este ensamble de modelos garantiza alta confiabilidad (92% de detección de inasistencias), robustez, escalabilidad y una clara mantenibilidad a largo plazo. El éxito de esta iniciativa, sin embargo, dependerá directamente del compromiso de la dirección, la adopción activa del personal, la fluidez de la integración técnica y el respeto irrestricto a los principios de privacidad y ética. Con esta propuesta integral, el Hospital de Apoyo María Auxiliadora se posicionará como un referente en el uso de inteligencia artificial aplicada a la salud pública en Perú.
